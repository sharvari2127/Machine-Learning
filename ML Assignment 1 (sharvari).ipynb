# %%
import pandas as pd
data = pd.read_csv("C:\\New folder\\WC_AT.csv")
data.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
data.isnull().sum()
# Out:
# Waist    0
# AT       0
# dtype: int64

# %%
data.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
import seaborn as sns
sns.distplot(data['Waist'])
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4484\409915301.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Waist'])
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(data['AT'])
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4484\3854675911.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['AT'])
# <Axes: xlabel='AT', ylabel='Density'>

# %%
import statsmodels.formula.api as smf
model = smf.ols("AT~Waist",data = data).fit()

# %%
sns.regplot(x="Waist", y="AT", data=data);

# %%
model.params
# Out:
# Intercept   -215.981488
# Waist          3.458859
# dtype: float64

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept    -9.909103
# Waist        14.740376
# dtype: float64
#  Intercept    8.197416e-17
# Waist        1.618607e-27
# dtype: float64

# %%
(model.rsquared)
# Out:
# 0.6700368930528429

# %%
newdata=pd.Series([120.20,124,80.22,130,145])

# %%
data_pred=pd.DataFrame(newdata,columns=['Waist'])

# %%
model.predict(data_pred)
# Out:
# 0    199.773411
# 1    212.917077
# 2     61.488212
# 3    233.670233
# 4    285.553124
# dtype: float64
